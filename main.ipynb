# %%
import pandas as pd

# %%
def find_element(el:str,target:str)->bool:
    if el.upper() in target.upper():
        return True
    return False

# %%
df = pd.read_csv("wticifes.csv")
df = df[["ano","titulo","autor","palavras_chave","categoria"]]
df.to_json("exemplo.json")

# %%
df
# Out:
#      ano                                             titulo  \
# 0   2019  Análise do Processo de Interações Acadêmicas A...
# 1   2019  Portal de Integração UFG - APIs de serviços pa...
# 2   2019  Processo de gerenciamento de riscos: um relato...
# 3   2019  Relato de Experiência: implantação de um siste...
# 4   2019  SeBaHo: Juntando o Util ao Necessário Serviço ...
# ..   ...                                                ...
# 65  2022  Sistema de Múltiplas Instâncias para Reserva d...
# 66  2022  Software Prod+: Eficiência e Automatização na ...
# 67  2022  Uma Metodologia Ágil para Mapeamento de Proces...
# 68  2022  Uma Proposta de Modelo de Desenvolvimento de G...
# 69  2022  Uma Solução para Gestão de Acessos aos Restaur...
#
#                                                 autor  \
# 0                                                 NaN
# 1   Andrey E. da Silva1, Bruno N. Machado, Jhonny ...
# 2   Núbia dos S. R. Santana dos Santos1, Henrique ...
# ...

# %%
df[df["ano"] == 2019]
# Out:
#      ano                                             titulo  \
# 0   2019  Análise do Processo de Interações Acadêmicas A...
# 1   2019  Portal de Integração UFG - APIs de serviços pa...
# 2   2019  Processo de gerenciamento de riscos: um relato...
# 3   2019  Relato de Experiência: implantação de um siste...
# 4   2019  SeBaHo: Juntando o Util ao Necessário Serviço ...
# 5   2019  SINAPSE: Sistema Integrado de Acompanhamento d...
# 6   2019  SisPAC – Sistema para Levantamento e Consolida...
# 7   2019  Sistema Eletrônico de Informações (Sei!): um e...
# 8   2019  Transformação de Projetos de Sistemas de Infor...
# 9   2019  UFPB-Sentinela: Um Sistema de Segurança para a...
# 10  2019  Uma Análise das faturas de telefonia fixa da U...
# 11  2019  Uma solução de automatização no processo de pa...
# 12  2019  Universidade Digital: Gerenciamento de Ordem d...
# 13  2019  Universidade Digital: preservando e disponibil...
# 14  2019  Utilização da Central de Ajuda para a Tecnolog...
# ...

# %% [markdown]
# # Importando os resumos

# %%
abstracts = []
txt = ''

with open("saida.txt") as saida:
    for line in saida:
        txt += line

abstracts = txt.split("SPLITMEHERE")

# %%
abstracts.__len__()
# Out:
# 61
